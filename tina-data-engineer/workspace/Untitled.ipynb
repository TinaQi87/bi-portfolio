# %%
import pandas as pd
import numpy as np

# %%
x = 10
name = "Alice"
price = 19.99
is_active = True

# %%
print(x)
# Out:
# 10

# %%
print(name)
# Out:
# Alice

# %%
print(name, price)
# Out:
# Alice 19.99

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "orange"

# %%
print(fruits[0])
# Out:
# orange

# %%
fruits.append("grape") 
print(fruits)
# Out:
# ['orange', 'banana', 'cherry', 'grape']

# %%
fruits.insert(1, "mango") 
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'cherry', 'grape']

# %%
last = fruits.pop() 
print(fruits)
# Out:
# ['orange', 'mango', 'banana']

# %%
print(len(fruits))
# Out:
# 3
